# %%
import optuna
storage = "mysql://optuna:AyHfbtAyAiRjR4ck@47.86.7.11/optuna"

# %%
study = optuna.load_study(study_name="mm-custom-30m-4",storage=storage)

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 study.stop()
#
# File ~\miniconda3\envs\market-making\Lib\site-packages\optuna\study\study.py:838, in Study.stop(self)
#     809 """Exit from the current optimization loop after the running trials finish.
#     810
#     811 This method lets the running :meth:`~optuna.study.Study.optimize` method return
#    (...)    834
#     835 """
#     837 if not self._thread_local.in_optimize_loop:
# --> 838     raise RuntimeError(
#     839         "`Study.stop` is supposed to be invoked inside an objective function or a "
#     840         "callback."
#     841     )
#     843 self._stop_flag = True
#
# RuntimeError: `Study.stop` is supposed to be invoked inside an objective function or a callback.

# %%
optuna.create_study(study_name="mm-custom-30m-4",directions=["maximize","maximize","maximize","maximize"], sampler=optuna.samplers.TPESampler(seed=42),storage=storage)
# Out:
# [I 2025-10-17 21:49:32,905] A new study created in RDB with name: mm-custom-30m-4

# %%
optuna.get_all_study_names(storage)
# Out:
# ['mm-custom-30m-2', 'mm-custom-30m-3']

# %%
optuna.delete_study("mm-custom-30m-2", storage=storage)
# Out:
# C:\Users\81393\AppData\Local\Temp\ipykernel_8864\136841509.py:1: FutureWarning: delete_study() got {'study_name'} as positional arguments but they were expected to be given as keyword arguments.
# Positional arguments ['study_name', 'storage'] in delete_study() have been deprecated since v3.0.0. They will be replaced with the corresponding keyword arguments in v5.0.0, so please use the keyword specification instead. See https://github.com/optuna/optuna/releases/tag/v3.0.0 for details.
#   optuna.delete_study("mm-custom-30m-2", storage="mysql://optuna:AyHfbtAyAiRjR4ck@47.86.7.11/optuna")
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 optuna.delete_study("mm-custom-30m-2", storage="mysql://optuna:AyHfbtAyAiRjR4ck@47.86.7.11/optuna")
#
# ...
